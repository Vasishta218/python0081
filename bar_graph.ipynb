# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasishta218/python0081/blob/main/bar_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pyplot graph
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([67, 87,97])
ypoints = np.array([87, 25,67])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting 4
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 11, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
#markers graph
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([9, 3, 6, 2])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
#pie chart 6
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["bat", "ball", "gloves", "inner thypad"]
mycolors = ["brown", "red", "orange", "blue"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#piechart 7
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
#piechart 8
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %%
#pie chart with shadow 5
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["bat", "Ball", "gloves", "shoe"]
myexplode = [0.2, 0, 0, 0.3]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
#plotting3
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8,31, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#histogram 2
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(87,50, 50)

plt.hist(x)
plt.show()

# %%
#histogram 1
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [177.64039103 163.33049541 174.4876304  160.87282706 193.10508639
#  167.07879246 173.62050987 158.2776395  173.93457521 167.91905548
#  155.60958544 175.09423916 160.68921944 178.24384187 159.77291324
#  174.09689231 168.07296221 181.19311857 162.5744081  152.74983136
#  167.29911618 172.65117943 172.85639878 174.62348913 171.95340505
#  176.02875293 142.2257695  196.18745239 163.9700852  143.55047504
#  192.51267465 164.7475614  179.64898999 186.8368784  172.79899969
#  162.30949793 193.25533163 172.9321331  149.62413417 172.89103913
#  168.87806051 178.45176328 180.78971249 176.87392931 161.47752994
#  151.29398974 180.11691273 156.57544328 160.81579368 167.18044074
#  193.84582585 181.89613178 169.24767578 163.51783969 153.39418576
#  158.71199484 176.33021553 170.25486122 157.54913612 171.88576113
#  168.15390822 156.50420248 160.32915438 168.49964743 185.41454706
#  168.69120411 170.63245649 183.57739233 167.43679664 177.93358253
# ...

# %%
#markers 1
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 0])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
#markers 2
...
plt.plot(ypoints, marker = '*')
...

# %%
#markers 3
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([33, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
#markers4
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([34, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
#markers5
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 2, mec = 'r')
plt.show()

# %%
#markers6
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 78, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
#markers7
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 88, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %%
#markers8
...
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
...

# %%
#markers9
...
plt.plot(ypoints, marker = 'o', ms = 2, mec = 'hotpink', mfc = 'hotpink')
...

# %%
#scatter graph1
import matplotlib.pyplot as plt
import numpy as np

x = np.array([6,2,1,6,8,18,21,7,1,81,23,7,4])
y = np.array([999,16,77,18,311,76,233,84,23,78,33,96,21])

plt.scatter(x, y)
plt.show()

# %%
#scater2
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
#scater3
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
#scater4
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
#scater5
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
#scater6
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
#scater7
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
#scater8
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
#scater9
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
#line graph 1
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 6, 3, 33])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
#line graph 2
plt.plot(ypoints, linestyle = 'dashed')

# %%
#line 3
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %%
#line 4
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([33, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
#line5
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
#line6
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
#label graps 1
import numpy as np
import matplotlib.pyplot as plt

x = np.array([8054, 853, 902, 952, 145, 123, 873, 183, 123, 234])
y = np.array([2400, 2500, 2600, 270090, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("cricketers")
plt.ylabel("population in differnt countries")

plt.show()

# %%
#label graph 2
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
#label graph 3
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
#label graph 4
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %%
#grid graph 1
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 925, 100, 105, 110, 115, 120, 125])
y = np.array([48, 58, 68, 78, 88, 98, 108, 118, 128, 138])

plt.title("semister marks")
plt.xlabel("average marks")
plt.ylabel("maximum")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
#grid graph 3
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
#grid graph 4
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
#grid graph 2
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
#plotting4
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([67, 87,97])
ypoints = np.array([87, 25,7778])

plt.plot(xpoints, ypoints,'o')
plt.show()

# %%
#bar graph1
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["biology","maths" ,"physcis"])
y = np.array([98, 87,75])

plt.bar(x, y)
plt.show()

# %%
#bar graph 2
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
#bar graph 3
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %%
#bar graph 4
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
#bar graph 5
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
#bar graph 6
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
#bar graph 7
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %%
#subplot1
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("marks")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("grades")

plt.show()

# %%
#subplot 2
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
#subplot3
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#subplot4
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %%
#subplot5
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
#piechart without shadow 4
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["match1", "match2", "match3", "match4"]
myexplode = [0.4, 0.1 , 0.1, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
#pie chart with 180 degrees 3
import matplotlib.pyplot as plt
import numpy as np

runs = np.array([47, 57, 67, 77])
mylabels = ["match 1", "match 2", "match 3", "match 4"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
#piechart2
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
#plotting 1
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([11, 58])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#nrml piechart 1
import matplotlib.pyplot as plt
import numpy as np

y = np.array([451,366,256,153])

plt.pie(y)
plt.show()
