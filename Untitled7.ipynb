# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasishta218/python0081/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([67, 87,97])
ypoints = np.array([87, 25z])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([67, 87,97])
ypoints = np.array([87, 25,7778])

plt.plot(xpoints, ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["biology","maths" ,"physcis"])
y = np.array([10000, 87678,756])

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([451,366,256,153])

plt.pie(y)
plt.show()
